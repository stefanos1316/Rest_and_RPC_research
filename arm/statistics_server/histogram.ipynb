# %%
import pandas as pd


filepath='grpc.txt' 
energy = pd.read_table(filepath, delim_whitespace=True, header=0, na_values=-1)
energy.head()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """
#    csharp    go   java  javascript    php  python  ruby
# 0       0  30.5  208.9         2.3  349.9    44.5  24.7
# 1       0  26.4  189.9         2.4  588.1    45.0  28.4
# 2       0  31.2  184.2         8.5  580.0    40.5  28.2
# 3       0  24.2  627.9         8.5  585.5    47.0  26.3
# 4       0  26.3  181.2         2.2  590.4    43.0  26.2

# %%
energy.describe()
# Out:
#        csharp         go        java  javascript         php     python  \
# count    48.0  48.000000   48.000000   46.000000   44.000000  47.000000
# mean      0.0  25.422917  277.804167    4.069565  573.150000  43.642553
# std       0.0   2.033469  211.444685    2.499499   49.895372   2.451862
# min       0.0  22.900000   10.000000    2.000000  349.900000  35.800000
# 25%       0.0  23.675000  176.775000    2.200000  579.525000  42.450000
# 50%       0.0  25.850000  182.150000    2.300000  585.350000  43.500000
# 75%       0.0  26.325000  488.075000    6.175000  588.300000  45.050000
# max       0.0  31.500000  805.200000   10.300000  618.700000  49.300000
#
#             ruby
# count  48.000000
# mean   26.904167
# std     1.274289
# min    24.400000
# 25%    26.075000
# 50%    26.300000
# 75%    28.200000
# max    30.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

ipc = filepath.split('.')

for column in energy:
    filename = ipc[0] + "_" + energy[column].name + ".pdf"
    newEnergy =energy[column].fillna(method='ffill')
    sns_plot = sns.distplot(newEnergy, hist=True)
    sns_plot.figure.savefig(filename)
    plt.figure()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-4-0a147e59ad9a> in <module>()
#       8     filename = ipc[0] + "_" + energy[column].name + ".pdf"
#       9     newEnergy =energy[column].fillna(method='ffill')
# ---> 10     sns_plot = sns.distplot(newEnergy, hist=True)
#      11     sns_plot.figure.savefig(filename)
#      12     plt.figure()
#
# /usr/local/lib/python2.7/dist-packages/seaborn/distributions.pyc in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# --> 231         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     232         if kde_color != color:
#     233             kde_kws["color"] = kde_color
#
# /usr/local/lib/python2.7/dist-packages/seaborn/distributions.pyc in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     689         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     690                                  gridsize, cut, clip, legend, ax,
# --> 691                                  cumulative=cumulative, **kwargs)
#     692
#     693     return ax
#
# /usr/local/lib/python2.7/dist-packages/seaborn/distributions.pyc in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     292                               "only implemented in statsmodels."
#     293                               "Please install statsmodels.")
# --> 294         x, y = _scipy_univariate_kde(data, bw, gridsize, cut, clip)
#     295
#     296     # Make sure the density is nonnegative
#
# /usr/local/lib/python2.7/dist-packages/seaborn/distributions.pyc in _scipy_univariate_kde(data, bw, gridsize, cut, clip)
#     364     """Compute a univariate kernel density estimate using scipy."""
#     365     try:
# --> 366         kde = stats.gaussian_kde(data, bw_method=bw)
#     367     except TypeError:
#     368         kde = stats.gaussian_kde(data)
#
# /usr/local/lib/python2.7/dist-packages/scipy/stats/kde.pyc in __init__(self, dataset, bw_method, weights)
#     206             self._neff = 1/sum(self._weights**2)
#     207
# --> 208         self.set_bandwidth(bw_method=bw_method)
#     209
#     210     def evaluate(self, points):
#
# /usr/local/lib/python2.7/dist-packages/scipy/stats/kde.pyc in set_bandwidth(self, bw_method)
#     538             raise ValueError(msg)
#     539
# --> 540         self._compute_covariance()
#     541
#     542     def _compute_covariance(self):
#
# /usr/local/lib/python2.7/dist-packages/scipy/stats/kde.pyc in _compute_covariance(self)
#     550                                                bias=False,
#     551                                                aweights=self.weights))
# --> 552             self._data_inv_cov = linalg.inv(self._data_covariance)
#     553
#     554         self.covariance = self._data_covariance * self.factor**2
#
# /usr/local/lib/python2.7/dist-packages/scipy/linalg/basic.pyc in inv(a, overwrite_a, check_finite)
#     972         inv_a, info = getri(lu, piv, lwork=lwork, overwrite_lu=1)
#     973     if info > 0:
# --> 974         raise LinAlgError("singular matrix")
#     975     if info < 0:
#     976         raise ValueError('illegal value in %d-th argument of internal '
#
# LinAlgError: singular matrix
