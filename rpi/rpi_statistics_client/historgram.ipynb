# %%
import pandas as pd


filepath='grpc.txt' 
energy = pd.read_table(filepath, delim_whitespace=True, header=0, na_values=-1)
energy.head()
# Out:
#    csharp    go   java  javascript    php  python  ruby
# 0       0  22.7  177.6         1.7  826.6    36.8   NaN
# 1       0  18.3  224.2        10.0  827.8    35.8  25.2
# 2       0  20.4  174.7         1.7  832.9    37.5  26.3
# 3       0  20.9  171.6         NaN  825.7    37.2  22.6
# 4       0  36.0  173.5        11.5  827.4    41.5  24.7

# %%
energy.describe()
# Out:
#        csharp         go        java  javascript         php     python  \
# count    53.0  53.000000   53.000000   45.000000   47.000000  45.000000
# mean      0.0  24.409434  233.671698    3.755556  820.891489  37.504444
# std       0.0   6.324411  178.089599    3.070946   99.262793   2.246913
# min       0.0  18.300000   23.500000    1.700000  174.600000  29.000000
# 25%       0.0  20.700000  170.900000    1.700000  827.600000  36.800000
# 50%       0.0  22.400000  173.300000    1.700000  838.300000  37.700000
# 75%       0.0  23.000000  180.000000    3.800000  847.400000  39.300000
# max       0.0  39.900000  630.500000   11.700000  869.100000  41.500000
#
#             ruby
# count  44.000000
# mean   25.036364
# std     1.196524
# min    22.600000
# 25%    24.600000
# 50%    24.900000
# 75%    25.450000
# max    27.200000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

ipc = filepath.split('.')

for column in energy:
    filename = ipc[0] + "_" + energy[column].name + ".pdf"
    newEnergy =energy[column].fillna(method='ffill')
    sns_plot = sns.distplot(newEnergy, hist=True)
    sns_plot.figure.savefig(filename)
    plt.figure()
    #sns.distplot(energy['go'], hist=True)
# Out:
# /usr/lib64/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /usr/lib64/python3.7/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /usr/lib64/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /usr/lib64/python3.7/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ...
