# %%
import pandas as pd

energy = pd.read_table("grpc.txt", delim_whitespace=True, header=0, na_values=-1)
energy.head()
# Out:
#    csharp    go   java  javascript    php  python  ruby
# 0       0  22.7  177.6         1.7  826.6    36.8   0.0
# 1       0  18.3  224.2        10.0  827.8    35.8  25.2
# 2       0  20.4  174.7         1.7  832.9    37.5  26.3
# 3       0  20.9  171.6         0.0  825.7    37.2  22.6
# 4       0  36.0  173.5        11.5  827.4    41.5  24.7

# %%
energy.describe()
# Out:
#        csharp         go        java  javascript         php     python  \
# count    53.0  53.000000   53.000000   53.000000   53.000000  53.000000
# mean      0.0  24.409434  233.671698    3.188679  727.960377  31.843396
# std       0.0   6.324411  178.089599    3.134035  278.688604  13.711513
# min       0.0  18.300000   23.500000    0.000000    0.000000   0.000000
# 25%       0.0  20.700000  170.900000    1.700000  820.700000  35.800000
# 50%       0.0  22.400000  173.300000    1.700000  834.600000  37.400000
# 75%       0.0  23.000000  180.000000    3.700000  845.400000  39.100000
# max       0.0  39.900000  630.500000   11.700000  869.100000  41.500000
#
#             ruby
# count  53.000000
# mean   20.784906
# std     9.552454
# min     0.000000
# 25%    23.000000
# 50%    24.800000
# 75%    25.300000
# max    27.200000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns_plot = sns.distplot(energy['ruby'], hist=True)
sns_plot.savefig("foo.pdf", bbox_inches='tight')
#sns.distplot(energy['go'], hist=True)

#for column in energy:
    #print(energy[column])
    #energy[column].hist()
    #plt.figure(column)
 #   sns.distplot(energy[column], hist=True)
# Out:
# /usr/lib64/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-ad67fdf45bea> in <module>()
#       4
#       5 sns.distplot(energy['ruby'], hist=True)
# ----> 6 sns.savefig("foo.pdf", bbox_inches='tight')
#       7 #sns.distplot(energy['go'], hist=True)
#       8
#
# AttributeError: module 'seaborn' has no attribute 'savefig'
