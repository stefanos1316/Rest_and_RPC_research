# %%
import pandas as pd


filepath='rest.txt' 
energy = pd.read_table(filepath, delim_whitespace=True, header=0, na_values=-1)
energy.head()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """
#    csharp     go    java  javascript      php  python     ruby
# 0  1780.8  445.8  1588.7        80.3  35023.1  2213.1  13176.0
# 1  1858.8  428.7  1614.0       197.3  34180.1  2177.2  13015.1
# 2  1778.2  415.6  1531.1        80.6  34799.8  2103.5  13037.2
# 3  1830.4  413.9  1639.8       168.3  34693.2  2216.4  13007.3
# 4  1868.5  388.2  1573.6       166.9  34353.8  2264.9  12985.6

# %%
energy.describe()
# Out:
#             csharp          go         java  javascript           php  \
# count    34.000000   34.000000    34.000000   34.000000     34.000000
# mean   1797.476471  413.597059  1565.070588  175.617647  34812.705882
# std      73.912262   22.327962   120.544654   46.007987   1219.391283
# min    1579.600000  383.500000   942.200000   80.300000  29368.900000
# 25%    1778.850000  391.300000  1560.550000  165.925000  34548.225000
# 50%    1801.450000  414.650000  1583.850000  171.450000  35018.500000
# 75%    1830.225000  418.725000  1609.450000  196.100000  35424.425000
# max    1918.400000  462.500000  1700.900000  314.100000  36235.200000
#
#             python          ruby
# count    32.000000     34.000000
# mean   2162.765625  13024.461765
# std      50.276222   2796.825984
# min    2049.000000   2385.100000
# 25%    2141.275000  13054.475000
# 50%    2164.150000  13183.300000
# 75%    2191.425000  13306.250000
# max    2264.900000  16111.700000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

ipc = filepath.split('.')

for column in energy:
    filename = ipc[0] + "_" + energy[column].name + ".pdf"
    newEnergy =energy[column].fillna(method='ffill')
    sns_plot = sns.distplot(newEnergy, hist=True)
    sns_plot.figure.savefig(filename)
    plt.figure()
