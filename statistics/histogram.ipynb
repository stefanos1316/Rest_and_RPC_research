# %%
import pandas as pd


filepath='re.txt' 
energy = pd.read_table(filepath, delim_whitespace=True, header=0, na_values=-1)
energy.head()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """
#    csharp     go     java  javascript     php  python    ruby
# 0   961.0  327.8  22472.0       168.1  2638.7  2035.9  1503.6
# 1   954.1  354.9  22568.2       195.1  2197.6  2092.5  1452.3
# 2   976.4  332.1  22578.3       167.8  2680.0  2069.4  1443.1
# 3   986.5  332.0  22380.5       167.3  2867.8  2164.3  1482.4
# 4   959.5  313.9  20930.1       140.4  2541.7  1966.8  1473.3

# %%
energy.describe()
# Out:
#             csharp          go          java  javascript          php  \
# count    34.000000   34.000000     29.000000   34.000000    34.000000
# mean    944.147059  343.285294  16329.010345  164.070588  2732.323529
# std      51.904261   32.564334  10087.539252   40.107118   150.031960
# min     813.900000  252.600000     26.000000   78.100000  2197.600000
# 25%     926.425000  319.725000   1143.500000  167.075000  2651.225000
# 50%     958.000000  344.050000  22380.500000  170.350000  2755.650000
# 75%     982.500000  362.100000  22611.900000  195.075000  2822.125000
# max    1026.000000  404.000000  22890.700000  252.900000  2982.600000
#
#             python         ruby
# count    34.000000    34.000000
# mean   2017.000000  1531.179412
# std     135.132649    75.052155
# min    1586.300000  1443.100000
# 25%    1951.725000  1487.025000
# 50%    2026.050000  1502.650000
# 75%    2105.450000  1541.625000
# max    2200.100000  1755.600000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

ipc = filepath.split('.')

for column in energy:
    filename = ipc[0] + "_" + energy[column].name + ".pdf"
    newEnergy =energy[column].fillna(method='ffill')
    sns_plot = sns.distplot(newEnergy, hist=True)
    sns_plot.figure.savefig(filename)
    plt.figure()
