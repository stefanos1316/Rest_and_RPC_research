# %% [markdown]
# import matplotlib
# import numpy as np
# import matplotlib.pyplot as plt
# from pylab import rcParams
# import matplotlib.ticker as ticker
#
# N = 21
# ind = np.arange(N)  # the x locations for the groups
# width = 0.17       # the width of the bars
#
# #fig = plt.figure()
# fig = plt.figure(figsize=(30,12))
# ax = fig.add_subplot(111)
#
#
#
#              606.7, 319.5, 637, 139.4, 458.2, 1899.2]
# rects1 = ax.bar(ind, stock_vals, width, color='r')
# meltdown_vals = [105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2040.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2674.5,
#                 588.7, 347, 370, 61.6, 513.5, 2191.2]
# rects2 = ax.bar(ind+width, meltdown_vals, width, color='g')
# spectre_vals = [55, 27, 44, 28, 16, 19, 35, 86, 42, 3, 10, 10, 479, 67, 628, 16, 73, 78, 55, 43, 304]
# rects3 = ax.bar(ind+width*2, spectre_vals, width, color='b')
#
#
# #plt.xticks(xtick_loc, xticks, rotation=90, ha="left")
# plt.xticks(fontsize=23, rotation=270)
# plt.yticks(fontsize=23)
# ax.set_ylabel('Energy (in Joules) and Run-Time (in Seconds)', fontsize=23)
# ax.set_xticks(ind+width)
# ax.set_xticklabels( ("C# gRPC", "C# RPC", "C# Rest", "Go gRPC", "Go RPC", "Go Rest", "Java gRPC", "Java RPC",
#                     "Java Rest", "JS gRPC", "JS RPC", "JS Rest", "PHP gRPC", "PHP RPC", "PHP Rest", "Python gRPC",
#                     "Python RPC", "Python Rest", "Ruby gRPC", "Ruby RPC", "Ruby Rest") )
# ax.legend( ('Client Energy', 'Server Energy', 'Nodes Run-Time'), fontsize=18 )
#
# def autolabel(rects):
#     for rect in rects:
#         h = rect.get_height()
#
#
# autolabel(rects1)
# autolabel(rects2)
# autolabel(rects3)
#
# #plt.show()
# plt.title('Energy-Delay Investigation of Remote Inter-Process Communication Technologies', fontsize=23)
# plt.savefig("energy_all_ondemand.pdf", bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 21
ind = np.arange(N)  # the x locations for the groups
width = 0.17       # the width of the bars

#fig = plt.figure()
fig = plt.figure(figsize=(30,12))
ax = fig.add_subplot(111)

#fig = plt.figure() fig = plt.figure(figsize=(30,12)) ax = fig.add_subplot(111)

stock_vals = [ 65.6, 399.9, 1206.6, 
              99, 84.8, 94.1, 
              451.5, 5224.5, 687, 
              28.2, 36.2, 88.1, 
              2543.9, 930.5, 1903,
              606.7, 319.5, 637,
              139.4, 458.2, 1899.2]
rects1 = ax.bar(ind, stock_vals, width, color='r')
meltdown_vals = [105.2, 364, 789.4,
                 105.8, 70.4, 79,
                 364, 2715.5, 617.8,
                 27, 32.3, 31.4,
                 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370,
                 61.6, 513.5, 2191.2]
rects2 = ax.bar(ind+width, meltdown_vals, width, color='g')
spectre_vals = [55, 27, 44, 
                28, 16, 19, 
                35, 855, 42, 
                3, 10, 10, 
                479, 67, 628,
                16, 73, 78, 
                55, 43, 304]
rects3 = ax.bar(ind+width*2, spectre_vals, width, color='b')

#plt.xticks(xtick_loc, xticks, rotation=90, ha="left")
plt.xticks(fontsize=23, rotation=270)
plt.yticks(fontsize=23)
ax.set_ylabel('Energy (in Joules) and Run-Time (in Seconds)', fontsize=23)
ax.set_xticks(ind+width)
ax.set_xticklabels( ("C# gRPC", "C# RPC", "C# Rest", "Go gRPC", "Go RPC", "Go Rest", "Java gRPC", "Java RPC", "Java Rest", "JS gRPC", "JS RPC", "JS Rest", "PHP gRPC", "PHP RPC", "PHP Rest", "Python gRPC", "Python RPC", "Python Rest", "Ruby gRPC", "Ruby RPC", "Ruby Rest") )
ax.legend( ('Client Energy', 'Server Energy', 'Nodes Run-Time'), fontsize=18 )

def autolabel(rects):
    for rect in rects: 
        h = rect.get_height()

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

#plt.show()
plt.title('Energy-Delay Investigation of Remote Inter-Process Communication Technologies', fontsize=23)
plt.savefig("intel_energy_performance_comparison.pdf", bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 21
ind = np.arange(N)  # the x locations for the groups
width = 0.17       # the width of the bars

#fig = plt.figure()
fig = plt.figure(figsize=(30,12))
ax = fig.add_subplot(111)

#fig = plt.figure() fig = plt.figure(figsize=(30,12)) ax = fig.add_subplot(111)

stock_vals = [0, 219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196]
rects1 = ax.bar(ind, stock_vals, width, color='r') 
meltdown_vals = [0, 290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
rects2 = ax.bar(ind+width, meltdown_vals, width, color='g')
spectre_vals = [0, 53, 68, 10, 7, 8, 71, 258, 77.4, 3, 22, 22, 331,28, 75, 18, 52, 75, 12, 42, 379]
rects3 = ax.bar(ind+width*2, spectre_vals, width, color='b')

#plt.xticks(xtick_loc, xticks, rotation=90, ha="left")
plt.xticks(fontsize=23, rotation=270)
plt.yticks(fontsize=23)
ax.set_ylabel('Energy (in Joules) and Run-Time (in Seconds)', fontsize=23)
ax.set_xticks(ind+width)
ax.set_xticklabels( ("C# gRPC", "C# RPC", "C# Rest", "Go gRPC", "Go RPC", "Go Rest", "Java gRPC", "Java RPC", "Java Rest", "JS gRPC", "JS RPC", "JS Rest", "PHP gRPC", "PHP RPC", "PHP Rest", "Python gRPC", "Python RPC", "Python Rest", "Ruby gRPC", "Ruby RPC", "Ruby Rest") )
ax.legend( ('Client Energy', 'Server Energy', 'Nodes Run-Time'), fontsize=18 )

def autolabel(rects):
    for rect in rects: 
        h = rect.get_height()

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

#plt.show()
plt.title('Energy-Delay Investigation of Remote Inter-Process Communication Technologies', fontsize=23)
plt.savefig("arm_energy_performance_comparison.pdf", bbox_inches='tight')

# %%
# Pearson's and Spearman's correlations for Intel Client and Server
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats


energy = [65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 687, 28.2, 36.2, 88.1, 930.5,
              606.7, 319.5, 637, 139.4, 458.2,
          105.2, 364, 789.4, 105.8, 70.4, 79, 364, 617.8, 27, 32.3, 31.4, 1214.6,
             588.7, 347, 370, 61.6, 513.5]
time = [55, 27, 44, 28, 16, 19, 35, 42, 3, 10, 10,  67, 16, 73, 78, 55, 43,
       55, 27, 44, 28, 16, 19, 35, 42, 3, 10, 10, 67, 16, 73, 78, 55, 43]

stats.pearsonr(energy, time) [0]   # Pearson's r
# Out:
# 0.46913543894135873

# %%
stats.spearmanr(energy, time).correlation    # Spearman's rho
# Out:
# 0.5613147160831379

# %%
# Out:
# 0.8902151955887152

# %%
# Out:
# 0.7639793552456613

# %%
result = scipy.stats.linregress(client_energy, time)
result.pvalue
# Out:
# 1.4093278294687077e-09

# %%
result = scipy.stats.linregress(server_energy, time)
result.pvalue
# Out:
# 6.517682793065014e-08

# %%
# Intel energy conusmption and run-time perfromance

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Energy = [65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
#               606.7, 319.5, 637, 139.4, 458.2, 1899.2,
#           105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
#              588.7, 347, 370, 61.6, 513.5, 2191.2]
# Time = [55, 27, 44, 28, 16, 19, 35, 855, 42, 3, 10, 10, 479, 67, 628, 16, 73, 78, 55, 43, 304,
#        55, 27, 44, 28, 16, 19, 35, 855, 42, 3, 10, 10, 479, 67, 628, 16, 73, 78, 55, 43, 304]
Energy = [65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 687, 28.2, 36.2, 88.1, 930.5,
              606.7, 319.5, 637, 139.4, 458.2,
          105.2, 364, 789.4, 105.8, 70.4, 79, 364, 617.8, 27, 32.3, 31.4, 1214.6,
             588.7, 347, 370, 61.6, 513.5]
Time = [55, 27, 44, 28, 16, 19, 35, 42, 3, 10, 10,  67, 16, 73, 78, 55, 43,
       55, 27, 44, 28, 16, 19, 35, 42, 3, 10, 10, 67, 16, 73, 78, 55, 43]
    
    
plt.figure(figsize=(8,5))
plt.ylabel("Energy Consumption (in Joules)", fontsize=17)
plt.xlabel("Run-Time Performance (in seconds)", fontsize=17)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
#plt.title("Energy-Delay Comparison of Intel Platform's Implementations")  
data_plot = pd.DataFrame({"Run-Time Performance (in seconds)":Time, "Energy Consumption (in Joules)":Energy})
sns.scatterplot(x = "Run-Time Performance (in seconds)", y = "Energy Consumption (in Joules)", data=data_plot)

plt.savefig("ipc_energy_delay_comparison_intel.pdf", bbox_inches='tight')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Energy = [219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196,
#          290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
# Time = [53, 68, 10, 7, 8, 71, 258, 77.4, 3, 22, 22, 331,28, 75, 18, 52, 75, 12, 42, 379,
#        53, 68, 10, 7, 8, 71, 258, 77.4, 3, 22, 22, 331,28, 75, 18, 52, 75, 12, 42, 379]
  
Energy = [219.3, 45.3, 10.8,
          5.2, 4.1, 83.5,
          33.9, 2.2,
          20.9, 18.3,
          7.7, 175.8, 11.7,
          31, 60.4, 8.3,
          33,
          
          290.7, 96.5, 6.9,
          6.6, 3.2, 75.6,
          43.5, 1.3,
          20.5, 18.3,
          8.8, 360.1, 16.5,
          36.5, 35, 8.3,
          35]

Time = [53, 68, 10,
        7, 8, 71,
        77.4, 3,
        22, 22,
        28, 75, 18,
        52, 75, 12,
        42,
        
        53, 68, 10,
        7, 8, 71,
        77.4, 3,
        22, 22,
        28, 75, 18,
        52, 75, 12,
        42]    
    
plt.figure(figsize=(8,5)) 
#plt.title("Energy-Delay Comparison of ARM Platform's Implementations")
plt.ylabel("Energy Consumption (in Joules)", fontsize=17)
plt.xlabel("Run-Time Performance (in seconds)", fontsize=17)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
data_plot = pd.DataFrame({"Run-Time Performance (in seconds)":Time, "Energy Consumption (in Joules)":Energy})
sns.scatterplot(y = "Energy Consumption (in Joules)", x = "Run-Time Performance (in seconds)", data=data_plot)
plt.ylabel("", fontsize=17)

plt.savefig("ipc_energy_delay_comparison_arm.pdf", bbox_inches='tight')

# %%
# ARM energy-time correlation test
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

energy = [219.3, 45.3, 10.8,
          5.2, 4.1, 83.5,
          33.9, 2.2,
          20.9, 18.3,
          7.7, 175.8, 11.7,
          31, 60.4, 8.3,
          33,
          
          290.7, 96.5, 6.9,
          6.6, 3.2, 75.6,
          43.5, 1.3,
          20.5, 18.3,
          8.8, 360.1, 16.5,
          36.5, 35, 8.3,
          35]

time = [53, 68, 10,
        7, 8, 71,
        77.4, 3,
        22, 22,
        28, 75, 18,
        52, 75, 12,
        42,
        
        53, 68, 10,
        7, 8, 71,
        77.4, 3,
        22, 22,
        28, 75, 18,
        52, 75, 12,
        42]    
    

stats.spearmanr(energy, time).correlation
# Out:
# 0.8890784930692023

# %%
stats.pearsonr(energy, time) [0]   # Pearson's r
# Out:
# 0.5477830723482362

# %%
# Pearson's and Spearman's correlations for Intel Client and Server MRSS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

energy_consumption = [ 65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
              606.7, 319.5, 637, 139.4, 458.2, 1899.2, 105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370, 61.6, 513.5, 2191.2]
mrss = [90, 102, 51, 117, 88, 72, 329, 168, 142, 407, 467, 457, 28, 26, 26, 26, 22, 19, 21, 26, 20,
        92, 142, 213, 161,124, 100, 328,171,6, 357, 98, 98, 47, 22, 40, 27, 22, 22, 23, 21, 487]

#scipy.stats.pearsonr(energy_consumption, mrss) [0]   # Pearson's r
stats.spearmanr(energy_consumption, mrss).correlation
# Out:
# -0.25383252863892813

# %%
stats.pearsonr(energy_consumption, mrss) [0]   # Pearson's r
# Out:
# -0.05717504565201739

# %%
# Pearson's and Spearman's correlations for Intel Client and Server MPF
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

energy_consumption = [ 65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
              606.7, 319.5, 637, 139.4, 458.2, 1899.2, 105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370, 61.6, 513.5, 2191.2]
mpf = [77, 83, 179, 216, 34, 30, 95, 50, 40, 99,113, 110, 4192, 1, 1, 7, 6, 7, 5, 6, 5,
      81, 128, 114, 55, 45, 38, 90, 50, 2, 86, 21, 21, 51, 1, 5208, 4, 26, 6, 5, 6, 128]

stats.spearmanr(energy_consumption, mpf).correlation  # Pearson's r
# Out:
# -0.04983983315082916

# %%
stats.pearsonr(energy_consumption, mpf) [0]
# Out:
# 0.35350619406130424

# %%
# Pearson's and Spearman's correlations for Intel Client and Server VCS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

energy_consumption = [ 65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
              606.7, 319.5, 637, 139.4, 458.2, 1899.2, 105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370, 61.6, 513.5, 2191.2]
vcs = [25, 85, 824, 136, 82, 149, 125, 65, 48, 1, 4, 4, 470, 40, 45, 20, 59, 58, 40, 84, 113,
      167, 151, 174, 137, 86, 121, 121, 85, 0.05, 0.5, 0.6, 0.6, 41, 32, 29, 266, 366, 215, 42, 76, 119]

stats.spearmanr(energy_consumption, vcs).correlation   # Pearson's r
# Out:
# 0.26142811171808344

# %%
stats.pearsonr(energy_consumption, vcs) [0]
# Out:
# 0.141233871717773

# %%
# Pearson's and Spearman's correlations for ARM Client and Server MRSS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

energy_consumption = [219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196,
         290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
mrss = [84, 49, 91, 69, 57, 66, 30, 29, 94, 94, 96, 20, 20, 20, 16, 17, 20, 10, 13, 14,
       84, 82, 93, 68, 57, 66, 32, 2, 79, 67, 70, 34, 15, 31, 17, 18, 18, 12, 12, 126]

stats.spearmanr(energy_consumption, mrss).correlation   # Pearson's r
# Out:
# -0.046150244710539065

# %%
stats.pearsonr(energy_consumption, mrss) [0]
# Out:
# 0.30573345482159164

# %%
# Pearson's and Spearman's correlations for ARM Client and Server MPF
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

energy_consumption = [219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196,
         290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
mpf = [213, 46, 34, 26, 24, 15, 5, 5, 21, 22, 22, 7974, 1, 1, 2, 5, 5, 16, 17, 2,
      243, 77, 35, 26, 25, 15, 6, 2, 17, 15, 16, 5, 1, 15, 2, 5, 4, 17, 13, 328]

stats.spearmanr(energy_consumption, mpf).correlation   # Pearson's r
# Out:
# -0.00014117044765270197

# %%
stats.pearsonr(energy_consumption, mpf) [0]
# Out:
# 0.2641374197667891

# %%
# Pearson's and Spearman's correlations for ARM Client and Server VCS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

energy_consumption = [219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196,
         290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
vcs = [108, 146, 66, 27, 50, 267, 17, 11, 0.1, 3, 3, 10, 10, 18, 5, 14, 19, 10, 26, 36,
      243, 81, 78, 33,37, 180, 4, 0.03, 0.08, 0.4,  0.4, 0.04, 8, 8, 84, 24, 5, 20, 13, 57]

stats.spearmanr(energy_consumption, vcs).correlation   # Pearson's r
# Out:
# 0.2192031596314243

# %%
stats.pearsonr(energy_consumption, vcs) [0]
# Out:
# 0.16064194407358315

# %%
# Intel Energy-MRSS
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
              606.7, 319.5, 637, 139.4, 458.2, 1899.2, 105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370, 61.6, 513.5, 2191.2]
mrss = [90, 102, 51, 117, 88, 72, 329, 168, 142, 407, 467, 457, 28, 26, 26, 26, 22, 19, 21, 26, 20,
        92, 142, 213, 161,124, 100, 328,171,6, 357, 98, 98, 47, 22, 40, 27, 22, 22, 23, 21, 487]

plt.figure(figsize=(8,5))
plt.ylabel("Energy Consumption (in Joules)", fontsize=17)
plt.xlabel("Maximum Resident Set Size (in MBs)", fontsize=17)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
#plt.title("Energy-MRSS Comparison of Intel Platform's Implementations", fontsize=15)  
data_plot = pd.DataFrame({"Maximum Resident Set Size (in MBs)":mrss, "Energy Consumption (in Joules)":Energy})
sns.scatterplot(x = "Maximum Resident Set Size (in MBs)", y = "Energy Consumption (in Joules)", data=data_plot)

plt.savefig("ipc_energy_mrss_comparison_intel.pdf", bbox_inches='tight')

# %%
# Intel Energy-MPF
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
              606.7, 319.5, 637, 139.4, 458.2, 1899.2, 105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370, 61.6, 513.5, 2191.2]
mpf = [77, 83, 179, 216, 34, 30, 95, 50, 40, 99,113, 110, 4192, 1, 1, 7, 6, 7, 5, 6, 5,
      81, 128, 114, 55, 45, 38, 90, 50, 2, 86, 21, 21, 51, 1, 5208, 4, 26, 6, 5, 6, 128]
   
plt.figure(figsize=(8,5))
plt.ylabel("Energy Consumption (in Joules)", fontsize=17)
plt.xlabel("Major Page Faults", fontsize=17)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
#plt.title("Energy-MPF Comparison of Intel Platform's Implementations", fontsize=15)  
data_plot = pd.DataFrame({"Energy Consumption (in Joules)":Energy, "Major Page Faults":mpf})
sns.scatterplot(y = "Energy Consumption (in Joules)", x = "Major Page Faults", data=data_plot)

plt.savefig("ipc_energy_mpf_comparison_intel.pdf", bbox_inches='tight')

# %%
# Intel Energy-VCS
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
              606.7, 319.5, 637, 139.4, 458.2, 1899.2, 105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370, 61.6, 513.5, 2191.2]
vcs = [25, 85, 824, 136, 82, 149, 125, 65, 48, 1, 4, 4, 470, 40, 45, 20, 59, 58, 40, 84, 113,
      167, 151, 174, 137, 86, 121, 121, 85, 0.05, 0.5, 0.6, 0.6, 41, 32, 29, 266, 366, 215, 42, 76, 119]
   
plt.figure(figsize=(8,5))
plt.ylabel("Energy Consumption (in Joules)", fontsize=17)
plt.xlabel("Voluntary Context Switches", fontsize=17)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
#plt.title("Energy-VCS Comparison of Intel Platform's Implementations", fontsize=15)  
data_plot = pd.DataFrame({"Energy Consumption (in Joules)":Energy, "Voluntary Context Switches":vcs})
sns.scatterplot(y = "Energy Consumption (in Joules)", x = "Voluntary Context Switches", data=data_plot)

plt.savefig("ipc_energy_vcs_comparison_intel.pdf", bbox_inches='tight')

# %%
# ARM Energy-MRSS
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196,
         290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
mrss = [84, 49, 91, 69, 57, 66, 30, 29, 94, 94, 96, 20, 20, 20, 16, 17, 20, 10, 13, 14,
       84, 82, 93, 68, 57, 66, 32, 2, 79, 67, 70, 34, 15, 31, 17, 18, 18, 12, 12, 126]

plt.figure(figsize=(8,5))
plt.ylabel("Energy Consumption (in Joules)", fontsize=17)
plt.xlabel("Maximum Resident Set Size (in MBs)", fontsize=17)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
#plt.title("Energy-MRSS Comparison of ARM Platform's Implementations", fontsize=15)  
data_plot = pd.DataFrame({"Energy Consumption (in Joules)":Energy, "Maximum Resident Set Size (in MBs)":mrss})
sns.scatterplot(y = "Energy Consumption (in Joules)", x = "Maximum Resident Set Size (in MBs)", data=data_plot)
plt.ylabel("", fontsize=17)
plt.savefig("ipc_energy_mrss_comparison_arm.pdf", bbox_inches='tight')

# %%
# ARM Energy-MPF
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196,
         290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
mpf = [213, 46, 34, 26, 24, 15, 5, 5, 21, 22, 22, 7974, 1, 1, 2, 5, 5, 16, 17, 2,
      243, 77, 35, 26, 25, 15, 6, 2, 17, 15, 16, 5, 1, 15, 2, 5, 4, 17, 13, 328]

plt.figure(figsize=(8,5))
plt.ylabel("Energy Consumption (in Joules)", fontsize=17)
plt.xlabel("Major Page Faults", fontsize=17)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
#plt.title("Energy-MPF Comparison of ARM Platform's Implementations", fontsize=15)  
data_plot = pd.DataFrame({"Energy Consumption (in Joules)":Energy, "Major Page Faults":mpf})
sns.scatterplot(y = "Energy Consumption (in Joules)", x = "Major Page Faults", data=data_plot)
plt.ylabel("", fontsize=17)

plt.savefig("ipc_energy_mpf_comparison_arm.pdf", bbox_inches='tight')

# %%
# ARM Energy-VCS
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196,
         290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
vcs = [108, 146, 66, 27, 50, 267, 17, 11, 0.1, 3, 3, 10, 10, 18, 5, 14, 19, 10, 26, 36,
      243, 81, 78, 33,37, 180, 4, 0.03, 0.08, 0.4,  0.4, 0.04, 8, 8, 84, 24, 5, 20, 13, 57]

plt.figure(figsize=(8,5))
plt.ylabel("Energy Consumption (in Joules)", fontsize=17)
plt.xlabel("Voluntary Context Switches", fontsize=17)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
#plt.title("Energy-MPF Comparison of ARM Platform's Implementations", fontsize=15)  
data_plot = pd.DataFrame({"Energy Consumption (in Joules)":Energy, "Voluntary Context Switches":vcs})
sns.scatterplot(y = "Energy Consumption (in Joules)", x = "Voluntary Context Switches", data=data_plot)
plt.ylabel("", fontsize=17)

plt.savefig("ipc_energy_vcs_comparison_arm.pdf", bbox_inches='tight')

# %%
# Energy Consumption and Run-Time Performance Comparison for Mitigations mechanisms
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [668.80, 1098.89, 861.79, 1224.64, 747.11,
          550.87, 556.29, 921.37, 1733.44, 336.24,
          385.87, 1604.45, 1517.73, 1715.16, 1515.01,
          1515.16, 695.23, 2437.62, 9077.59, 477.00,
          495.00, 7413.92, 1005.78, 447.21, 2222.32,
          10198.29, 1801.99, 430.46, 1467.15, 259.03,
          780.83, 2385.10, 2269.53, 732.21, 1016.26,
          1121.24, 9398.18, 6249.17, 532.64, 578.35,
          1824.65, 603.94, 578.48, 3414.72, 41889.66,
          695.64, 1750.30, 323.96, 1520.58, 680.50,
          7945.03, 19095.09, 4093.85, 1348.47, 1074.34,
          2566.95, 506.31, 1681.50, 233.08, 227.81,
          218.86, 216.56, 242.26, 464.51, 460.53,
          220.85, 221.25, 439.64, 231.41, 230.34,
          712.35, 217.42, 1672.90, 8030.24, 6110.83,
          9828.48, 1596.44, 3760.13, 13685.02,
          12476.34, 5808.97, 12936.17, 2895.95, 205.45,
          408.38, 1627.24, 386.44, 594.73, 387.29,
          590.19, 553.98, 555.86, 555.26, 35116.54,
          7458.07, 1009.11, 879.72, 2340.46, 2099.55,
          311.74, 27196.69, 361.61, 3145.81, 867.78, 
          692.70, 1166.79, 1167.15, 1166.98, 1167.83,
          1169.88, 1025.00, 1319.11, 911.60, 752.24,
          1108.47, 519.94, 812.20, 1309.01, 1125.50,
          2267.37, 289.74, 211.45, 3056.64, 5440.59,
          2561.48, 3242.57, 3882.23, 3884.82, 3882.32,
          3876.67, 3969.34, 3962.63, 3961.76, 3980.70,
          431.62, 397.23, 383.65, 382.69, 423.31,
          16539.63, 612.19, 1309.43, 908.26, 717.57,
          1796.16, 5426.34, 4908.41, 5030.69, 5206.09,
          5609.52, 5821.56, 6014.54, 892.86, 333.48,
          2957.24, 1111.36, 234.67, 292.69, 661.15,
          1076.91, 8645.46, 18236.49, 1991.90, 2499.00,
Time = [88, 18, 38, 32, 24,
        24, 26, 38, 37, 15,
        10, 80, 122, 121, 122,
        122, 30, 117, 418, 23,
        20, 304, 44, 8, 51,
        175, 42, 20, 34, 5,
        39, 62, 52, 13, 17,
        56, 188, 102, 27, 28,
        83, 24, 22, 90, 657,
        35, 88, 15, 65, 30,
        359, 948, 107, 40, 28,
        175, 13, 30, 10, 10,
        10, 10, 10, 21, 21,
        10, 10, 20, 10, 10,
        30, 10, 72, 392, 289,
        270, 30, 60, 625,
        574, 261, 633, 57, 8,
        17, 69, 12, 21, 12,
        21, 20, 20, 20, 637,
        131, 17, 15, 47, 37,
        9, 573, 15, 52, 38,
        24, 36, 36, 36, 36,
        36, 24, 45, 18, 14,
        21, 10, 18, 26, 19,
        65, 14, 6, 64, 276,
        50, 81, 140, 140, 140,
        140, 140, 140, 140, 140,
        22, 20, 20, 20, 20,
        345, 26, 23, 130, 89,
        223, 654, 720, 720, 720,
        720, 720, 721, 108, 47,
        395, 154, 14, 5, 28,
        46, 307, 480, 193, 70,
        20, 31, 24, 13, 15,
        15, 15, 183, 183, 183,
        24, 97, 22, 91, 24, 12,
        27, 9, 15, 47, 6, 46,
        120, 67, 9, 72, 35,
        34, 13, 20, 10, 13,
        31, 18, 8, 9, 502,
        30, 30, 30, 23, 19,
        15, 9, 21, 204, 200,
        335, 202 ,24 ,40 ,77,
        76, 76, 27, 60, 48,
        14, 19, 55, 183, 31,
        137, 117, 147, 33, 33,
        28, 60, 22, 20, 30,
        20, 44, 24, 22, 29,
        28, 80, 84, 36, 33,
        534, 37, 14, 52, 44,
        267, 30, 30, 31, 30,
        38, 34, 25, 375, 95,
        9, 851, 195, 128, 20,
        106, 146, 305, 84, 35,
        42, 70, 30, 232, 243,
        419, 659, 312, 315, 439,
        721, 332, 332, 332, 332,
        144, 140, 90, 139, 10,
        20, 24, 30, 52, 52,
        886, 885, 885, 885, 358,
        789, 31, 61, 62, 361,
        105,244,14,
       86,18,38,38,28,24,26,38,37,15,10,80,121,121,121,121,29,117,418,23,20,306,44,8,51,184,42,20,34,5,40,62,52,13,18,169,189,102,27,28,83,24,22,90,664,35,88,15,65,30,358,948,108,41,28,168,12,30,10,10,10,10,10,21,21,10,10,20,10,10,30,10,72,390,288,270,30,60,623,572,262,633,57,8,17,69,17,29,17,29,28,27,27,638,131,17,15,47,37,10,572,15,52,38,25,55,54,54,54,54,24,45,18,13,22,13,17,28,21,65,14,7,64,264,50,81,140,140,140,140,140,140,140,140,22,20,20,20,20,350,25,23,134,91,231,670,720,720,720,720,720,721,112,47,396,153,15,5,28,47,307,481,194,71,21,31,24,13,15,15,15,177,177,178,25,98,23,91,24,12,27,9,15,47,6,46,120,67,9,72,35,34,13,21,10,13,31,18,8,9,502,30,30,30,27,21,18,10,22,203,203,334,205,24,46,78,77,77,27,60,48,14,19,55,184,31,137,117,148,33,33,28,60,22,20,30,20,44,24,22,31,28,82,85,36,33,546,37,14,52,44,267,30,30,30,30,38,34,25,382,94,10,858,197,130,20,106,146,305,84,35,42,70,30,232,243,418,656,312,315,438,720,332,332,332,332,162,155,104,155,16,20,24,30,52,52,886,885,886,886,362,779,31,61,62,361,105,245,14,
29,14,24,22,20,30,26,65,14,7,62,275,50,81,141,141,141,141,140,140,140,140,22,20,20,20,20,359,26,23,134,93,232,678,720,720,720,720,720,721,109,47,398,155,15,6,28,48,310,482,198,71,21,31,24,13,15,15,15,205,187,188,25,99,23,92,24,12,27,9,16,48,6,47,122,68,10,73,35,35,13,22,10,13,30,19,8,9,502,30,30,30,29,22,19,11,23,207,202,346,197,24,49,78,77,77,27,60,48,14,19,55,184,31,137,117,148,33,33,28,61,22,20,30,20,44,24,22,32,28,84,85,36,33,554,37,14,53,45,267,30,30,30,31,38,34,25,382,95,10,864,196,134,20,106,146,305,84,35,42,70,30,233,244,419,659,312,315,440,724,332,332,332,332,168,160,106,161,26,21,24,30,53,53,890,889,888,887,360,784,31,61,62,361,105,245,14
       ]
    
    
plt.figure(figsize=(8,5))
plt.ylabel("Energy Consumption (in Joules)", fontsize=17)
plt.xlabel("Run-Time Performance (in seconds)", fontsize=17)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
#plt.title("Energy-Delay Comparison of Intel Platform's Implementations")  
data_plot = pd.DataFrame({"Run-Time Performance (in seconds)":Time, "Energy Consumption (in Joules)":Energy})
sns.scatterplot(x = "Run-Time Performance (in seconds)", y = "Energy Consumption (in Joules)", data=data_plot)

plt.savefig("safeguards_energy_delay_comparison_mitigations.pdf", bbox_inches='tight')

# %%
# Shapiro-Wilk Test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import shapiro
from scipy import stats

# normality test
stat, p = shapiro(data_plot)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
	print('Sample does not look Gaussian (reject H0)')
    
stats.spearmanr(Energy, Time).correlation
# Out:
# Statistics=0.384, p=0.000
# Sample does not look Gaussian (reject H0)
# 0.9078090348127533

# %%
# Energy Consumption and Run-Time Performance Comparison for GCC mechanisms
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [
    974,1053,758,1324,784,2133,1764,369,344,329,329,366,33774,1273,1541,1271,1274,332,3194,591,1481,281,1354,578,6902,16269,1690,1697,1692,1661,1954,1816,482,5308,8875,4795,4917,4982,5190,421,188,2783,1240,2542,23450,2063,5640,1636,599,278,7988,1528,7016,5371,1208,9101,854,2132,5449,262,261,1530,3336,12076,10940,5235,10884,2738,11344,187,371,1479,6660,953,1662,490,708,503,704,664,667,663,386,32840,6937,962,833,2052,1992,567,855,529,544,444,1018,5633,777,993,1010,3086,2968,1826,2959,210,934,1256,1161,3600,3606,3604,3610,3667,3680,3672,3684,1781,1780,1771,1772,1772,604,1263,1074,809,868,728,1274,971,869,1630,1347,2104,252,883,245,5373,1905,2217,3743,2175,484,441,190,2519,3007,1953,755,1078,1179,648,957,2967,1398,359,
    911,1057,754,1324,781,2141,1761,379,357,331,330,376,31779,1373,1548,1372,1371,377,3225,593,1504,282,1362,593,6967,16510,1685,1704,1686,1662,1959,1845,494,5416,8933,4733,4890,4916,5102,429,192,3195,1228,2625,24386,2009,5736,1636,602,279,8026,1541,7008,5525,1248,9092,887,2157,6432,264,256,1533,3325,12131,10921,5065,11247,2749,10846,186,369,1474,6723,969,1669,505,717,513,720,672,672,671,384,32903,6955,965,836,2071,2005,577,819,534,559,447,1002,5801,793,1020,1037,3077,2943,1815,2974,216,934,1272,1208,3541,3555,3549,3551,3635,3645,3642,3638,1784,1779,1788,1786,1788,610,1279,1075,829,870,746,1289,975,868,1694,1352,2110,253,1017,246,5249,1906,2262,3780,2208,499,438,190,2512,3121,1990,781,1123,1146,650,962,3087,1408,357,
    136,18,38,36,40,65,53,22,20,20,20,20,650,121,121,121,121,15,94,35,89,15,65,30,358,953,30,30,31,31,38,34,24,319,190,720,720,720,720,24,30,367,187,77,618,178,140,30,28,6,419,73,393,290,25,279,127,307,965,33,33,30,60,626,569,261,636,57,392,8,17,70,309,34,37,19,31,19,30,29,29,29,20,368,131,17,15,47,37,28,23,19,11,23,148,104,30,30,30,146,140,91,140,9,22,41,25,142,142,142,142,142,142,142,142,0,0,0,0,0,29,25,166,39,19,13,26,22,20,31,26,67,14,22,5,281,288,313,547,306,24,25,6,50,60,48,15,20,26,11,18,79,81,11,
    140,18,38,36,40,65,52,22,20,20,20,20,591,121,121,121,121,17,92,35,88,15,65,30,359,950,30,30,31,31,38,34,24,319,189,720,720,720,720,24,30,364,185,79,623,192,142,30,28,6,419,73,391,290,24,278,123,281,668,33,33,30,60,625,567,263,633,57,360,8,17,70,309,35,37,18,29,18,29,28,28,28,20,638,131,17,15,47,37,28,22,19,11,23,134,104,30,30,30,145,140,91,140,9,22,41,24,141,141,141,141,141,141,141,141,65,64,65,65,64,30,24,170,39,18,13,25,21,20,30,26,66,14,23,5,283,274,302,549,305,24,25,6,50,60,48,14,20,26,11,17,81,81,11,
    141,18,38,36,39,64,53,22,20,20,20,20,583,121,121,121,121,15,94,35,88,15,65,30,358,952,30,30,30,30,38,34,24,319,189,720,720,720,720,25,30,367,187,76,610,180,139,30,28,6,419,73,396,290,24,278,123,292,599,33,33,30,60,624,568,263,621,57,362,8,17,70,308,34,37,18,30,18,29,28,28,28,20,638,131,17,15,47,38,27,23,19,11,23,138,102,30,30,30,145,140,90,140,9,21,41,23,141,142,142,142,141,141,141,141,64,64,64,64,64,29,24,166,39,18,14,26,21,20,31,26,66,14,21,5,280,273,305,552,307,24,25,6,50,59,48,14,19,26,11,18,79,81,11,
    141,18,38,36,40,65,52,22,20,20,20,20,633,121,121,121,121,17,94,35,88,15,65,30,359,950,30,30,31,30,38,34,24,318,189,720,720,720,720,25,30,381,184,82,619,229,141,30,28,6,419,73,393,289,24,278,120,307,636,33,33,30,60,626,568,265,635,57,368,8,17,70,307,35,37,18,30,18,30,28,28,28,20,638,131,17,15,47,38,28,23,20,11,23,138,105,30,30,30,145,140,91,140,9,22,41,24,142,142,142,142,141,141,141,142,65,65,65,65,65,29,24,173,39,18,14,26,21,20,31,26,66,14,23,5,282,277,311,557,311,24,25,6,50,60,48,14,20,26,11,18,81,80,11
]
    
    
plt.figure(figsize=(8,5))
plt.ylabel("Energy Consumption (in Joules)", fontsize=17)
plt.xlabel("Run-Time Performance (in seconds)", fontsize=17)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
#plt.title("Energy-Delay Comparison of Intel Platform's Implementations")  
data_plot = pd.DataFrame({"Run-Time Performance (in seconds)":Time, "Energy Consumption (in Joules)":Energy})
sns.scatterplot(x = "Run-Time Performance (in seconds)", y = "Energy Consumption (in Joules)", data=data_plot)

plt.savefig("safeguards_energy_delay_comparison_gcc.pdf", bbox_inches='tight')

# %%
# Shapiro-Wilk Test
from numpy.random import seed
from numpy.random import randn
from scipy.stats import shapiro

# normality test
stat, p = shapiro(data_plot)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
	print('Sample does not look Gaussian (reject H0)')
    
stats.spearmanr(Energy, Time).correlation
# Out:
# Statistics=0.406, p=0.000
# Sample does not look Gaussian (reject H0)
# 0.8396922612730254
