# %% [markdown]
# import matplotlib
# import numpy as np
# import matplotlib.pyplot as plt
# from pylab import rcParams
# import matplotlib.ticker as ticker
#
# N = 21
# ind = np.arange(N)  # the x locations for the groups
# width = 0.17       # the width of the bars
#
# #fig = plt.figure()
# fig = plt.figure(figsize=(30,12))
# ax = fig.add_subplot(111)
#
#
#
#              606.7, 319.5, 637, 139.4, 458.2, 1899.2]
# rects1 = ax.bar(ind, stock_vals, width, color='r')
# meltdown_vals = [105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2040.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2674.5,
#                 588.7, 347, 370, 61.6, 513.5, 2191.2]
# rects2 = ax.bar(ind+width, meltdown_vals, width, color='g')
# spectre_vals = [55, 27, 44, 28, 16, 19, 35, 86, 42, 3, 10, 10, 479, 67, 628, 16, 73, 78, 55, 43, 304]
# rects3 = ax.bar(ind+width*2, spectre_vals, width, color='b')
#
#
# #plt.xticks(xtick_loc, xticks, rotation=90, ha="left")
# plt.xticks(fontsize=23, rotation=270)
# plt.yticks(fontsize=23)
# ax.set_ylabel('Energy (in Joules) and Run-Time (in Seconds)', fontsize=23)
# ax.set_xticks(ind+width)
# ax.set_xticklabels( ("C# gRPC", "C# RPC", "C# Rest", "Go gRPC", "Go RPC", "Go Rest", "Java gRPC", "Java RPC",
#                     "Java Rest", "JS gRPC", "JS RPC", "JS Rest", "PHP gRPC", "PHP RPC", "PHP Rest", "Python gRPC",
#                     "Python RPC", "Python Rest", "Ruby gRPC", "Ruby RPC", "Ruby Rest") )
# ax.legend( ('Client Energy', 'Server Energy', 'Nodes Run-Time'), fontsize=18 )
#
# def autolabel(rects):
#     for rect in rects:
#         h = rect.get_height()
#
#
# autolabel(rects1)
# autolabel(rects2)
# autolabel(rects3)
#
# #plt.show()
# plt.title('Energy-Delay Investigation of Remote Inter-Process Communication Technologies', fontsize=23)
# plt.savefig("energy_all_ondemand.pdf", bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 21
ind = np.arange(N)  # the x locations for the groups
width = 0.17       # the width of the bars

#fig = plt.figure()
fig = plt.figure(figsize=(30,12))
ax = fig.add_subplot(111)

#fig = plt.figure() fig = plt.figure(figsize=(30,12)) ax = fig.add_subplot(111)

stock_vals = [ 65.6, 399.9, 1206.6, 
              99, 84.8, 94.1, 
              451.5, 5224.5, 687, 
              28.2, 36.2, 88.1, 
              2543.9, 930.5, 1903,
              606.7, 319.5, 637,
              139.4, 458.2, 1899.2]
rects1 = ax.bar(ind, stock_vals, width, color='r')
meltdown_vals = [105.2, 364, 789.4,
                 105.8, 70.4, 79,
                 364, 2715.5, 617.8,
                 27, 32.3, 31.4,
                 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370,
                 61.6, 513.5, 2191.2]
rects2 = ax.bar(ind+width, meltdown_vals, width, color='g')
spectre_vals = [55, 27, 44, 
                28, 16, 19, 
                35, 855, 42, 
                3, 10, 10, 
                479, 67, 628,
                16, 73, 78, 
                55, 43, 304]
rects3 = ax.bar(ind+width*2, spectre_vals, width, color='b')

#plt.xticks(xtick_loc, xticks, rotation=90, ha="left")
plt.xticks(fontsize=23, rotation=270)
plt.yticks(fontsize=23)
ax.set_ylabel('Energy (in Joules) and Run-Time (in Seconds)', fontsize=23)
ax.set_xticks(ind+width)
ax.set_xticklabels( ("C# gRPC", "C# RPC", "C# Rest", "Go gRPC", "Go RPC", "Go Rest", "Java gRPC", "Java RPC", "Java Rest", "JS gRPC", "JS RPC", "JS Rest", "PHP gRPC", "PHP RPC", "PHP Rest", "Python gRPC", "Python RPC", "Python Rest", "Ruby gRPC", "Ruby RPC", "Ruby Rest") )
ax.legend( ('Client Energy', 'Server Energy', 'Nodes Run-Time'), fontsize=18 )

def autolabel(rects):
    for rect in rects: 
        h = rect.get_height()

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

#plt.show()
plt.title('Energy-Delay Investigation of Remote Inter-Process Communication Technologies', fontsize=23)
plt.savefig("intel_energy_performance_comparison.pdf", bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 21
ind = np.arange(N)  # the x locations for the groups
width = 0.17       # the width of the bars

#fig = plt.figure()
fig = plt.figure(figsize=(30,12))
ax = fig.add_subplot(111)

#fig = plt.figure() fig = plt.figure(figsize=(30,12)) ax = fig.add_subplot(111)

stock_vals = [0, 219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196]
rects1 = ax.bar(ind, stock_vals, width, color='r') 
meltdown_vals = [0, 290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
rects2 = ax.bar(ind+width, meltdown_vals, width, color='g')
spectre_vals = [0, 53, 68, 10, 7, 8, 71, 258, 77.4, 3, 22, 22, 331,28, 75, 18, 52, 75, 12, 42, 379]
rects3 = ax.bar(ind+width*2, spectre_vals, width, color='b')

#plt.xticks(xtick_loc, xticks, rotation=90, ha="left")
plt.xticks(fontsize=23, rotation=270)
plt.yticks(fontsize=23)
ax.set_ylabel('Energy (in Joules) and Run-Time (in Seconds)', fontsize=23)
ax.set_xticks(ind+width)
ax.set_xticklabels( ("C# gRPC", "C# RPC", "C# Rest", "Go gRPC", "Go RPC", "Go Rest", "Java gRPC", "Java RPC", "Java Rest", "JS gRPC", "JS RPC", "JS Rest", "PHP gRPC", "PHP RPC", "PHP Rest", "Python gRPC", "Python RPC", "Python Rest", "Ruby gRPC", "Ruby RPC", "Ruby Rest") )
ax.legend( ('Client Energy', 'Server Energy', 'Nodes Run-Time'), fontsize=18 )

def autolabel(rects):
    for rect in rects: 
        h = rect.get_height()

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

#plt.show()
plt.title('Energy-Delay Investigation of Remote Inter-Process Communication Technologies', fontsize=23)
plt.savefig("arm_energy_performance_comparison.pdf", bbox_inches='tight')

# %%
# Pearson's and Spearman's correlations for Intel Client and Server
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats


client_energy = [ 65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
              606.7, 319.5, 637, 139.4, 458.2, 1899.2]
server_energy = [105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370, 61.6, 513.5, 2191.2]
time = [55, 27, 44, 28, 16, 19, 35, 855, 42, 3, 10, 10, 479, 67, 628, 16, 73, 78, 55, 43, 304]

scipy.stats.pearsonr(client_energy, time) [0]   # Pearson's r
# Out:
# 0.9278232585165954

# %%
scipy.stats.spearmanr(client_energy, time).correlation    # Spearman's rho
# Out:
# 0.7754309827883429

# %%
scipy.stats.pearsonr(server_energy, time) [0]   # Pearson's r
# Out:
# 0.8902151955887152

# %%
scipy.stats.spearmanr(server_energy, time).correlation    # Spearman's rho
# Out:
# 0.7639793552456613

# %%
result = scipy.stats.linregress(client_energy, time)
result.pvalue
# Out:
# 1.4093278294687077e-09

# %%
result = scipy.stats.linregress(server_energy, time)
result.pvalue
# Out:
# 6.517682793065014e-08

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
              606.7, 319.5, 637, 139.4, 458.2, 1899.2, 105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370, 61.6, 513.5, 2191.2]
Time = [55, 27, 44, 28, 16, 19, 35, 855, 42, 3, 10, 10, 479, 67, 628, 16, 73, 78, 55, 43, 304,
       55, 27, 44, 28, 16, 19, 35, 855, 42, 3, 10, 10, 479, 67, 628, 16, 73, 78, 55, 43, 304]
   
plt.figure(figsize=(8,5)) 
plt.title("Energy-Delay Comparison of Intel Platform's Implementations")  
data_plot = pd.DataFrame({"Energy Consumption (in Joules)":Energy, "Run-Time Performance (in seconds)":Time})
sns.scatterplot(x = "Energy Consumption (in Joules)", y = "Run-Time Performance (in seconds)", data=data_plot)

plt.savefig("ipc_energy_delay_comparison_intel.pdf", bbox_inches='tight')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196,
         290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
Time = [53, 68, 10, 7, 8, 71, 258, 77.4, 3, 22, 22, 331,28, 75, 18, 52, 75, 12, 42, 379,
       53, 68, 10, 7, 8, 71, 258, 77.4, 3, 22, 22, 331,28, 75, 18, 52, 75, 12, 42, 379]
   
plt.figure(figsize=(8,5)) 
plt.title("Energy-Delay Comparison of ARM Platform's Implementations")  
data_plot = pd.DataFrame({"Energy Consumption (in Joules)":Energy, "Run-Time Performance (in seconds)":Time})
sns.scatterplot(x = "Energy Consumption (in Joules)", y = "Run-Time Performance (in seconds)", data=data_plot)

plt.savefig("ipc_energy_delay_comparison_arm.pdf", bbox_inches='tight')

# %%
# Pearson's and Spearman's correlations for Intel Client and Server MRSS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

energy_consumption = [ 65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
              606.7, 319.5, 637, 139.4, 458.2, 1899.2, 105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370, 61.6, 513.5, 2191.2]
mrss = [90, 102, 51, 117, 88, 72, 329, 168, 142, 407, 467, 457, 28, 26, 26, 26, 22, 19, 21, 26, 20,
        92, 142, 213, 161,124, 100, 328,171,6, 357, 98, 98, 47, 22, 40, 27, 22, 22, 23, 21, 487]

scipy.stats.pearsonr(energy_consumption, mrss) [0]   # Pearson's r
# Out:
# -0.05717504565201739

# %%
# Pearson's and Spearman's correlations for Intel Client and Server MPF
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

energy_consumption = [ 65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
              606.7, 319.5, 637, 139.4, 458.2, 1899.2, 105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370, 61.6, 513.5, 2191.2]
mpf = [77, 83, 179, 216, 34, 30, 95, 50, 40, 99,113, 110, 4192, 1, 1, 7, 6, 7, 5, 6, 5,
      81, 128, 114, 55, 45, 38, 90, 50, 2, 86, 21, 21, 51, 1, 5208, 4, 26, 6, 5, 6, 128]

scipy.stats.pearsonr(energy_consumption, mpf) [0]   # Pearson's r
# Out:
# 0.35350619406130424

# %%
# Pearson's and Spearman's correlations for Intel Client and Server VCS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

energy_consumption = [ 65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
              606.7, 319.5, 637, 139.4, 458.2, 1899.2, 105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370, 61.6, 513.5, 2191.2]
vcs = [25, 85, 824, 136, 82, 149, 125, 65, 48, 1, 4, 4, 470, 40, 45, 20, 59, 58, 40, 84, 113,
      167, 151, 174, 137, 86, 121, 121, 85, 0.05, 0.5, 0.6, 0.6, 41, 32, 29, 266, 366, 215, 42, 76, 119]

scipy.stats.pearsonr(energy_consumption, vcs) [0]   # Pearson's r
# Out:
# 0.141233871717773

# %%
# Pearson's and Spearman's correlations for ARM Client and Server MRSS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

energy_consumption = [219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196,
         290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
mrss = [84, 49, 91, 69, 57, 66, 30, 29, 94, 94, 96, 20, 20, 20, 16, 17, 20, 10, 13, 14,
       84, 82, 93, 68, 57, 66, 32, 2, 79, 67, 70, 34, 15, 31, 17, 18, 18, 12, 12, 126]

scipy.stats.pearsonr(energy_consumption, mrss) [0]   # Pearson's r
# Out:
# 0.30573345482159164

# %%
# Pearson's and Spearman's correlations for ARM Client and Server MPF
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

energy_consumption = [219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196,
         290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
mpf = [213, 46, 34, 26, 24, 15, 5, 5, 21, 22, 22, 7974, 1, 1, 2, 5, 5, 16, 17, 2,
      243, 77, 35, 26, 25, 15, 6, 2, 17, 15, 16, 5, 1, 15, 2, 5, 4, 17, 13, 328]

scipy.stats.pearsonr(energy_consumption, mpf) [0]   # Pearson's r
# Out:
# 0.2641374197667891

# %%
# Pearson's and Spearman's correlations for ARM Client and Server VCS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

energy_consumption = [219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196,
         290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
vcs = [108, 146, 66, 27, 50, 267, 17, 11, 0.1, 3, 3, 10, 10, 18, 5, 14, 19, 10, 26, 36,
      243, 81, 78, 33,37, 180, 4, 0.03, 0.08, 0.4,  0.4, 0.04, 8, 8, 84, 24, 5, 20, 13, 57]

scipy.stats.pearsonr(energy_consumption, vcs) [0]   # Pearson's r
# Out:
# 0.16064194407358315

# %%
# Intel Energy-MRSS
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
              606.7, 319.5, 637, 139.4, 458.2, 1899.2, 105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370, 61.6, 513.5, 2191.2]
mrss = [90, 102, 51, 117, 88, 72, 329, 168, 142, 407, 467, 457, 28, 26, 26, 26, 22, 19, 21, 26, 20,
        92, 142, 213, 161,124, 100, 328,171,6, 357, 98, 98, 47, 22, 40, 27, 22, 22, 23, 21, 487]

plt.figure(figsize=(8,5))
plt.xlabel("Energy Consumption (in Joules)", fontsize=15)
plt.ylabel("Maximum Resident Set Size (in MBs)", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Energy-MRSS Comparison of Intel Platform's Implementations", fontsize=15)  
data_plot = pd.DataFrame({"Energy Consumption (in Joules)":Energy, "Maximum Resident Set Size (in MBs)":mrss})
sns.scatterplot(x = "Energy Consumption (in Joules)", y = "Maximum Resident Set Size (in MBs)", data=data_plot)

plt.savefig("ipc_energy_mrss_comparison_intel.pdf", bbox_inches='tight')

# %%
# Intel Energy-MPF
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
              606.7, 319.5, 637, 139.4, 458.2, 1899.2, 105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370, 61.6, 513.5, 2191.2]
mpf = [77, 83, 179, 216, 34, 30, 95, 50, 40, 99,113, 110, 4192, 1, 1, 7, 6, 7, 5, 6, 5,
      81, 128, 114, 55, 45, 38, 90, 50, 2, 86, 21, 21, 51, 1, 5208, 4, 26, 6, 5, 6, 128]
   
plt.figure(figsize=(8,5))
plt.xlabel("Energy Consumption (in Joules)", fontsize=15)
plt.ylabel("Major Page Faults", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Energy-MPF Comparison of Intel Platform's Implementations", fontsize=15)  
data_plot = pd.DataFrame({"Energy Consumption (in Joules)":Energy, "Major Page Faults":mpf})
sns.scatterplot(x = "Energy Consumption (in Joules)", y = "Major Page Faults", data=data_plot)

plt.savefig("ipc_energy_mpf_comparison_intel.pdf", bbox_inches='tight')

# %%
# Intel Energy-VCS
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [65.6, 399.9, 1206.6, 99, 84.8, 94.1, 451.5, 5224.5, 687, 28.2, 36.2, 88.1, 2543.9, 930.5, 1903,
              606.7, 319.5, 637, 139.4, 458.2, 1899.2, 105.2, 364, 789.4, 105.8, 70.4, 79, 364, 2715.5, 617.8, 27, 32.3, 31.4, 1291.3, 1214.6, 2274.5,
                 588.7, 347, 370, 61.6, 513.5, 2191.2]
vcs = [25, 85, 824, 136, 82, 149, 125, 65, 48, 1, 4, 4, 470, 40, 45, 20, 59, 58, 40, 84, 113,
      167, 151, 174, 137, 86, 121, 121, 85, 0.05, 0.5, 0.6, 0.6, 41, 32, 29, 266, 366, 215, 42, 76, 119]
   
plt.figure(figsize=(8,5))
plt.xlabel("Energy Consumption (in Joules)", fontsize=15)
plt.ylabel("Voluntary Context Switches", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Energy-VCS Comparison of Intel Platform's Implementations", fontsize=15)  
data_plot = pd.DataFrame({"Energy Consumption (in Joules)":Energy, "Voluntary Context Switches":vcs})
sns.scatterplot(x = "Energy Consumption (in Joules)", y = "Voluntary Context Switches", data=data_plot)

plt.savefig("ipc_energy_vcs_comparison_intel.pdf", bbox_inches='tight')

# %%
# ARM Energy-MRSS
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196,
         290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
mrss = [84, 49, 91, 69, 57, 66, 30, 29, 94, 94, 96, 20, 20, 20, 16, 17, 20, 10, 13, 14,
       84, 82, 93, 68, 57, 66, 32, 2, 79, 67, 70, 34, 15, 31, 17, 18, 18, 12, 12, 126]

plt.figure(figsize=(8,5))
plt.xlabel("Energy Consumption (in Joules)", fontsize=15)
plt.ylabel("Maximum Resident Set Size (in MBs)", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Energy-MRSS Comparison of ARM Platform's Implementations", fontsize=15)  
data_plot = pd.DataFrame({"Energy Consumption (in Joules)":Energy, "Maximum Resident Set Size (in MBs)":mrss})
sns.scatterplot(x = "Energy Consumption (in Joules)", y = "Maximum Resident Set Size (in MBs)", data=data_plot)

plt.savefig("ipc_energy_mrss_comparison_arm.pdf", bbox_inches='tight')

# %%
# ARM Energy-MPF
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196,
         290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
mpf = [213, 46, 34, 26, 24, 15, 5, 5, 21, 22, 22, 7974, 1, 1, 2, 5, 5, 16, 17, 2,
      243, 77, 35, 26, 25, 15, 6, 2, 17, 15, 16, 5, 1, 15, 2, 5, 4, 17, 13, 328]

plt.figure(figsize=(8,5))
plt.xlabel("Energy Consumption (in Joules)", fontsize=15)
plt.ylabel("Major Page Faults", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Energy-MPF Comparison of ARM Platform's Implementations", fontsize=15)  
data_plot = pd.DataFrame({"Energy Consumption (in Joules)":Energy, "Major Page Faults":mpf})
sns.scatterplot(x = "Energy Consumption (in Joules)", y = "Major Page Faults", data=data_plot)

plt.savefig("ipc_energy_mpf_comparison_arm.pdf", bbox_inches='tight')

# %%
# ARM Energy-VCS
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Energy = [219.3, 45.3, 10.8, 5.2, 4.1, 83.5, 73.3, 33.9, 2.2, 20.9, 18.3, 348.7, 7.7, 175.8, 11.7, 31, 60.4, 8.3, 33, 196,
         290.7, 96.5, 6.9, 6.6, 3.2, 75.6, 40.6, 43.5, 1.3, 20.5, 18.3, 88.7, 8.8, 360.1, 16.5, 36.5, 35, 8.3, 35, 1094]
vcs = [108, 146, 66, 27, 50, 267, 17, 11, 0.1, 3, 3, 10, 10, 18, 5, 14, 19, 10, 26, 36,
      243, 81, 78, 33,37, 180, 4, 0.03, 0.08, 0.4,  0.4, 0.04, 8, 8, 84, 24, 5, 20, 13, 57]

plt.figure(figsize=(8,5))
plt.xlabel("Energy Consumption (in Joules)", fontsize=15)
plt.ylabel("Voluntary Context Switches", fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Energy-MPF Comparison of ARM Platform's Implementations", fontsize=15)  
data_plot = pd.DataFrame({"Energy Consumption (in Joules)":Energy, "Voluntary Context Switches":vcs})
sns.scatterplot(x = "Energy Consumption (in Joules)", y = "Voluntary Context Switches", data=data_plot)

plt.savefig("ipc_energy_vcs_comparison_arm.pdf", bbox_inches='tight')
